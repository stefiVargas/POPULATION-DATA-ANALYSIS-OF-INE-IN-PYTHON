# %% [markdown]
# ### Conexion al INE

# %%
#Importamos las bibliotecas

# %%
pip install requests #instalo la libreria requests

# %%
import pandas as pd
import requests
import datetime


#1.definimos una  función que nos permita la conexion al INE. Esta toma un código del INE y devuelve un json 
#con los datos del INE, nos conecta con el INE

def ine_request(ine_code):  
    resultados = 999
    path_template = 'http://servicios.ine.es/wstempus/js/ES/DATOS_SERIE/{cod_serie}?nult={n_ult_datos}'
    path = path_template.format(cod_serie=ine_code, n_ult_datos=resultados) 
    json_request = requests.get(path).json()  
    
    return json_request  


#2. Lectura del archivo de códigos del INE

df_codigos = pd.read_excel('ine_codes.xlsx') 


#3.Transformación en lista  la columna de codigos del INE del dataframe df_codigos y la guardamos en la variable codigos

codigos = df_codigos['ine_code'].tolist()


fecha_lista = []
variable_lista = list()
valor_lista = list()

# 4.Creamos un bucle for que recorre la lista (codigos) con los códigos del INE, ine_codes

for codigo in codigos:
    
    # Cargo en 'datos' el resultado de la función ine_request()
    datos = ine_request(codigo)
    
    # Cargo en nombre_variable 
    
    nombre_variable = datos['Nombre']
    
    # Toma los atributos de cada serie de datos
    
    for dato in datos['Data']:

        fecha = datetime.date.fromtimestamp(dato['Fecha'] // 1000)
        valor = dato['Valor']
        fecha_lista.append(fecha)
        variable_lista.append(nombre_variable)
        valor_lista.append(valor)

#5. crea un dataframe con todas las listas de datos       

df = pd.DataFrame({
        'Fecha': fecha_lista,
        'Dato' : variable_lista,
        'Población' : valor_lista
    })

# Graba el dataframe en un excel

df.to_excel('tabla_ine.xlsx', index=False)

# %%
df_codigos
# Out:
#    ine_code         descrición
# 0     CP335          población
# 1  CP300335  población hombres
# 2  CP300334  población mujeres

# %%
df_codigos['ine_code']
# Out:
# 0       CP335
# 1    CP300335
# 2    CP300334
# Name: ine_code, dtype: object

# %%
df_codigos['ine_code'].tolist()
# Out:
# ['CP335', 'CP300335', 'CP300334']

# %%
ine_request
# Out:
# <function __main__.ine_request(ine_code)>

# %%
datos  #vemos que la primera parte de datos es un diccionario y no es tabular, los datos no están bien organizados
# Out:
# {'COD': 'CP300334',
#  'Nombre': 'Total Nacional. Todas las edades. Mujeres. Población. Número. ',
#  'FK_Unidad': 3,
#  'FK_Escala': 1,
#  'Data': [{'Fecha': 31532400000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 26,
#    'Anyo': 1971,
#    'Valor': 17398898.0,
#    'Secreto': False},
#   {'Fecha': 47170800000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 27,
#    'Anyo': 1971,
#    'Valor': 17485953.0,
#    'Secreto': False},
#   {'Fecha': 63068400000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 26,
#    'Anyo': 1972,
#    'Valor': 17580397.0,
#    'Secreto': False},
#   {'Fecha': 78793200000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 27,
#    'Anyo': 1972,
#    'Valor': 17672353.0,
#    'Secreto': False},
#   {'Fecha': 94690800000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 26,
#    'Anyo': 1973,
#    'Valor': 17772628.0,
#    'Secreto': False},
#   {'Fecha': 110329200000,
#    'FK_TipoDato': 1,
#    'FK_Periodo': 27,
#    'Anyo': 1973,
#    'Valor': 17860714.0,
#    'Secreto': False},
# ...

# %%
datos['Nombre']
# Out:
# 'Total Nacional. Todas las edades. Mujeres. Población. Número. '

# %%
nombre_variable  #cargamos en esta variable la clave 'nombre' del diccionario
# Out:
# 'Total Nacional. Todas las edades. Mujeres. Población. Número. '

# %%
datos['Data'] #solo nos interesa traernos los datos de fecha y valor del diccionario. Cada uno de los elementos de  
## la lista es un diccionario
# Out:
# [{'Fecha': 31532400000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 26,
#   'Anyo': 1971,
#   'Valor': 17398898.0,
#   'Secreto': False},
#  {'Fecha': 47170800000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 27,
#   'Anyo': 1971,
#   'Valor': 17485953.0,
#   'Secreto': False},
#  {'Fecha': 63068400000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 26,
#   'Anyo': 1972,
#   'Valor': 17580397.0,
#   'Secreto': False},
#  {'Fecha': 78793200000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 27,
#   'Anyo': 1972,
#   'Valor': 17672353.0,
#   'Secreto': False},
#  {'Fecha': 94690800000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 26,
#   'Anyo': 1973,
#   'Valor': 17772628.0,
#   'Secreto': False},
#  {'Fecha': 110329200000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 27,
#   'Anyo': 1973,
#   'Valor': 17860714.0,
#   'Secreto': False},
#  {'Fecha': 126226800000,
#   'FK_TipoDato': 1,
#   'FK_Periodo': 26,
#   'Anyo': 1974,
#   'Valor': 17957230.0,
#   'Secreto': False},
#  {'Fecha': 141861600000,
# ...

# %%
datos['Data'] [0] # es una lista de diccionarios
# Out:
# {'Fecha': 31532400000,
#  'FK_TipoDato': 1,
#  'FK_Periodo': 26,
#  'Anyo': 1971,
#  'Valor': 17398898.0,
#  'Secreto': False}

# %%
type(datos['Data'][0])
# Out:
# dict

# %%
len(datos['Data'] ) #este el nº de veces que recorre el bucle for los datos del ine
# Out:
# 104

# %%
fecha = datetime.date.fromtimestamp(dato['Fecha'] // 1000)

# %%
len(fecha_lista) ## todas las lista tienen la misma cantidad de datos
# Out:
# 312

# %%
df
# Out:
#           Fecha                                               Dato   Población
# 0    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...  34040642.0
# 1    1971-06-30  Total Nacional. Todas las edades. Total. Pobla...  34216856.0
# 2    1971-12-31  Total Nacional. Todas las edades. Total. Pobla...  34408338.0
# 3    1972-06-30  Total Nacional. Todas las edades. Total. Pobla...  34595886.0
# 4    1972-12-31  Total Nacional. Todas las edades. Total. Pobla...  34800600.0
# ..          ...                                                ...         ...
# 307  2020-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24146903.0
# 308  2020-12-31  Total Nacional. Todas las edades. Mujeres. Pob...  24171413.0
# 309  2021-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24140027.0
# 310  2021-12-31  Total Nacional. Todas las edades. Mujeres. Pob...  24195741.0
# 311  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24304407.0
#
# [312 rows x 3 columns]

# %%
#Renombramos las columnas. para que se puedan aplicar los cambios al df hay que usar inplace = True

# %%
df.rename(columns= {'Fecha': 'fecha','Dato':'dato', 'Población':'poblacion'}, inplace = True)

# %%
df
# Out:
#           fecha                                               dato   poblacion
# 0    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...  34040642.0
# 1    1971-06-30  Total Nacional. Todas las edades. Total. Pobla...  34216856.0
# 2    1971-12-31  Total Nacional. Todas las edades. Total. Pobla...  34408338.0
# 3    1972-06-30  Total Nacional. Todas las edades. Total. Pobla...  34595886.0
# 4    1972-12-31  Total Nacional. Todas las edades. Total. Pobla...  34800600.0
# ..          ...                                                ...         ...
# 307  2020-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24146903.0
# 308  2020-12-31  Total Nacional. Todas las edades. Mujeres. Pob...  24171413.0
# 309  2021-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24140027.0
# 310  2021-12-31  Total Nacional. Todas las edades. Mujeres. Pob...  24195741.0
# 311  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...  24304407.0
#
# [312 rows x 3 columns]

# %% [markdown]
# ### Exploramos 'Poblacion'

# %%
max(df.poblacion) / 1000000
# Out:
# 47.615034

# %%
min(df.poblacion) / 1000000
# Out:
# 16.641744

# %% [markdown]
# ### Exploramos 'fecha'

# %%
max(df.fecha)
# Out:
# datetime.date(2022, 6, 30)

# %%
min(df.fecha)
# Out:
# datetime.date(1970, 12, 31)

# %% [markdown]
# ### Formateo de la columna 'dato'

# %%
df.dato[0]
# Out:
# 'Total Nacional. Todas las edades. Total. Población. Número. '

# %%
# la columna dato contiene un string con varios valores. Nos interesa extraer el índice 2 que es: total, mujeres y hombres

# %%
df.dato[311]
# Out:
# 'Total Nacional. Todas las edades. Mujeres. Población. Número. '

# %%
df.dato[110]
# Out:
# 'Total Nacional. Todas las edades. Hombres. Población. Número. '

# %%
# para poder separar, divivir los nombres de la columna dato debemos usar el método split. como es un método de la clase
#string hay que indicarlo para que no nos de error y pueda ser usado con la series de pandas

# %%
df.dato[0].split('. ')[2] #hacemos un split para cortar y  extraer parte del string, en este caso, total indice 2
# Out:
# 'Total'

# %%
df.dato.str.split('. ').str.get(5)
# Out:
# 0        Total
# 1        Total
# 2        Total
# 3        Total
# 4        Total
#         ...
# 307    Mujeres
# 308    Mujeres
# 309    Mujeres
# 310    Mujeres
# 311    Mujeres
# Name: dato, Length: 312, dtype: object

# %%
df['dato_2'] = df.dato.str.split('. ').str.get(5) #cargamos los valores extraidos en una nueva columna llamada dato_2

# %%
df
# Out:
#           fecha                                               dato  \
# 0    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 1    1971-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 2    1971-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 3    1972-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 4    1972-12-31  Total Nacional. Todas las edades. Total. Pobla...
# ..          ...                                                ...
# 307  2020-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 308  2020-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 309  2021-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 310  2021-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 311  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
#
#       poblacion   dato_2
# 0    34040642.0    Total
# 1    34216856.0    Total
# 2    34408338.0    Total
# 3    34595886.0    Total
# 4    34800600.0    Total
# ...

# %%
## anteriormente no podiamos filtrar por hombres o mujeres porque la columna dato contenía varios valores
## al separar el índice 2  ya podemos filtrar por estos dos valores (hombres, mujeres)

# %%
df[df.dato_2 == 'Mujeres' ]
# Out:
#           fecha                                               dato  \
# 208  1970-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 209  1971-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 210  1971-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 211  1972-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 212  1972-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# ..          ...                                                ...
# 307  2020-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 308  2020-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 309  2021-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 310  2021-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 311  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
#
#       poblacion   dato_2
# 208  17398898.0  Mujeres
# 209  17485953.0  Mujeres
# 210  17580397.0  Mujeres
# 211  17672353.0  Mujeres
# 212  17772628.0  Mujeres
# ...

# %% [markdown]
# ### 1.- ¿Cómo ha ido variando la población a lo largo de los años? ¿Han variado los máximos y los mínimos o los rangos?

# %%
df[df.dato_2 == 'Total' ].poblacion.max()/1000000
# Out:
# 47.615034

# %%
df[df.dato_2 == 'Mujeres' ].poblacion.max()/1000000
# Out:
# 24.304407

# %%
df[df.dato_2 == 'Hombres' ].poblacion.max()/1000000
# Out:
# 23.310627

# %%
df[df.dato_2 == 'Total' ].poblacion.min()/1000000
# Out:
# 34.040642

# %%
df[df.dato_2 == 'Mujeres' ].poblacion.min()/1000000
# Out:
# 17.398898

# %%
df[df.dato_2 == 'Hombres' ].poblacion.min()/1000000
# Out:
# 16.641744

# %%
df[df.dato_2 == 'Mujeres' ].fecha.max()
# Out:
# datetime.date(2022, 6, 30)

# %%
df[df.dato_2 == 'Hombres' ].fecha.max()
# Out:
# datetime.date(2022, 6, 30)

# %%
df[df.dato_2 == 'Total' ].fecha.max()
# Out:
# datetime.date(2022, 6, 30)

# %%
df[df.dato_2 == 'Mujeres' ].fecha.min()
# Out:
# datetime.date(1970, 12, 31)

# %%
df[df.dato_2 == 'Hombres' ].fecha.min()
# Out:
# datetime.date(1970, 12, 31)

# %%
df[df.dato_2 == 'Total' ].fecha.min()
# Out:
# datetime.date(1970, 12, 31)

# %%
#Usamos groupby para obtener los datos de las tres categorias en un solo dataframe

# %%
df.groupby('dato_2').max()
# Out:
#               fecha                                               dato  \
# dato_2
# Hombres  2022-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# Mujeres  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# Total    2022-06-30  Total Nacional. Todas las edades. Total. Pobla...
#
#           poblacion
# dato_2
# Hombres  23310627.0
# Mujeres  24304407.0
# Total    47615034.0

# %%
df.groupby('dato_2').min()
# Out:
#               fecha                                               dato  \
# dato_2
# Hombres  1970-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# Mujeres  1970-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# Total    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...
#
#           poblacion
# dato_2
# Hombres  16641744.0
# Mujeres  17398898.0
# Total    34040642.0

# %%
## par poder filtrar por varias funciones en un solo dataframe usamos la funcion aggregate. -- df.groupby().aggregate()

# %%
df.groupby('dato_2').aggregate(['max','min','mean'])
# Out:
# /var/folders/7k/fzl9cvvd65d33d4pbghcq6n40000gn/T/ipykernel_39167/1508499587.py:1: FutureWarning: ['fecha', 'dato'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('dato_2').aggregate(['max','min','mean'])
#           poblacion
#                 max         min          mean
# dato_2
# Hombres  23310627.0  16641744.0  2.020241e+07
# Mujeres  24304407.0  17398898.0  2.094578e+07
# Total    47615034.0  34040642.0  4.114819e+07

# %%
#Estudiar la evolución de la población para ello usaremos la media

# %%
#en el calculo de la media anterior nos dan unos numeros cientificos. Debemos transformalo a un formato normal para 
#poder procesarlos

# %%
df.groupby('dato_2').poblacion.transform('mean').apply(lambda x: format (x, '0.2f'))
# Out:
# 0      41148193.47
# 1      41148193.47
# 2      41148193.47
# 3      41148193.47
# 4      41148193.47
#           ...
# 307    20945782.89
# 308    20945782.89
# 309    20945782.89
# 310    20945782.89
# 311    20945782.89
# Name: poblacion, Length: 312, dtype: object

# %%
df['medias_pob']=df.groupby('dato_2').poblacion.transform('mean').apply(lambda x: format (x, '0.2f'))

# %%
df

# %%
df.medias_pob.dtype
# Out:
# dtype('O')

# %%
#cambiamos el formato de medias_pob a formato float, para poder restarlo con poblacion

# %%
df.medias_pob.apply(lambda x: float (x))
# Out:
# 0      41148193.47
# 1      41148193.47
# 2      41148193.47
# 3      41148193.47
# 4      41148193.47
#           ...
# 307    20945782.89
# 308    20945782.89
# 309    20945782.89
# 310    20945782.89
# 311    20945782.89
# Name: medias_pob, Length: 312, dtype: float64

# %%
df.medias_pob= df.medias_pob.apply(lambda x: float (x))

# %%
df.poblacion - df.medias_pob
# Out:
# 0     -7107551.47
# 1     -6931337.47
# 2     -6739855.47
# 3     -6552307.47
# 4     -6347593.47
#           ...
# 307    3201120.11
# 308    3225630.11
# 309    3194244.11
# 310    3249958.11
# 311    3358624.11
# Length: 312, dtype: float64

# %%
# cargamos la diferencia de la poblacion y medias_pob en una nueva columna

# %%
df['diferencia_medias_pob']= df.poblacion - df.medias_pob

# %%
df
# Out:
#           fecha                                               dato  \
# 0    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 1    1971-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 2    1971-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 3    1972-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 4    1972-12-31  Total Nacional. Todas las edades. Total. Pobla...
# ..          ...                                                ...
# 307  2020-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 308  2020-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 309  2021-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 310  2021-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 311  2022-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
#
#       poblacion   dato_2   medias_pob  diferencia_medias_pob
# 0    34040642.0    Total  41148193.47            -7107551.47
# ...

# %% [markdown]
# ### 2. ¿Cuál es la tasa de crecimiento/decrecimiento de la población? ¿ha variado a lo largo de los años?

# %%
pd.set_option('display.max_rows',500)

# %%
df[(df.diferencia_medias_pob < 0) & (df.dato_2 == 'Hombres')]  #nos devuelve los años y valores en los cuales 

# los hombres han estado por debajo de la media. Vemos que los datos son consecutivos, por tanto, podemos
# decir que ha habido un crecimiento lineal.
# Out:
#           fecha                                               dato  \
# 104  1970-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 105  1971-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 106  1971-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 107  1972-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 108  1972-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 109  1973-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 110  1973-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 111  1974-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 112  1974-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 113  1975-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 114  1975-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 115  1976-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 116  1976-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# ...

# %%
df[(df.diferencia_medias_pob < 0) & (df.dato_2 == 'Mujeres')]
# Out:
#           fecha                                               dato  \
# 208  1970-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 209  1971-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 210  1971-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 211  1972-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 212  1972-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 213  1973-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 214  1973-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 215  1974-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 216  1974-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 217  1975-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 218  1975-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 219  1976-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 220  1976-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# ...

# %%
df[(df.diferencia_medias_pob < 0) & (df.dato_2 == 'Total')]
# Out:
#          fecha                                               dato   poblacion  \
# 0   1970-12-31  Total Nacional. Todas las edades. Total. Pobla...  34040642.0
# 1   1971-06-30  Total Nacional. Todas las edades. Total. Pobla...  34216856.0
# 2   1971-12-31  Total Nacional. Todas las edades. Total. Pobla...  34408338.0
# 3   1972-06-30  Total Nacional. Todas las edades. Total. Pobla...  34595886.0
# 4   1972-12-31  Total Nacional. Todas las edades. Total. Pobla...  34800600.0
# 5   1973-06-30  Total Nacional. Todas las edades. Total. Pobla...  34980317.0
# 6   1973-12-31  Total Nacional. Todas las edades. Total. Pobla...  35177294.0
# 7   1974-06-30  Total Nacional. Todas las edades. Total. Pobla...  35363890.0
# 8   1974-12-31  Total Nacional. Todas las edades. Total. Pobla...  35569375.0
# 9   1975-06-30  Total Nacional. Todas las edades. Total. Pobla...  35750033.0
# 10  1975-12-31  Total Nacional. Todas las edades. Total. Pobla...  35946425.0
# ...

# %%
df = df.assign(valor_previo_pob = lambda row: row.poblacion.shift(1),   #shift nos permite movernos entre filas 
               incremento_pob = lambda row: row.poblacion - row.poblacion.shift (1))

# %%
# el incremento nos permite calcular los años en los que ha habido un aumento.En este caso de la población,
# si el incremento es negativo <0 es porque el año anterior hubo menos gente que el año actual con el que se está
#comparando

# %%
df
# Out:
#           fecha                                               dato  \
# 0    1970-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 1    1971-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 2    1971-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 3    1972-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 4    1972-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 5    1973-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 6    1973-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 7    1974-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 8    1974-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 9    1975-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 10   1975-12-31  Total Nacional. Todas las edades. Total. Pobla...
# 11   1976-06-30  Total Nacional. Todas las edades. Total. Pobla...
# 12   1976-12-31  Total Nacional. Todas las edades. Total. Pobla...
# ...

# %%
import numpy as np

df.loc[208, ['valor_previo_pob', 'incremento_pob']] = np.nan

# %%
import numpy as np

df.loc[104, ['valor_previo_pob', 'incremento_pob']] = np.nan

# %%
df [df.dato_2 == 'Hombres']
# Out:
#           fecha                                               dato  \
# 104  1970-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 105  1971-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 106  1971-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 107  1972-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 108  1972-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 109  1973-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 110  1973-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 111  1974-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 112  1974-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 113  1975-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 114  1975-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# 115  1976-06-30  Total Nacional. Todas las edades. Hombres. Pob...
# 116  1976-12-31  Total Nacional. Todas las edades. Hombres. Pob...
# ...

# %%
df [df.dato_2 == 'Mujeres']
# Out:
#           fecha                                               dato  \
# 208  1970-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 209  1971-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 210  1971-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 211  1972-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 212  1972-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 213  1973-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 214  1973-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 215  1974-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 216  1974-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 217  1975-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 218  1975-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# 219  1976-06-30  Total Nacional. Todas las edades. Mujeres. Pob...
# 220  1976-12-31  Total Nacional. Todas las edades. Mujeres. Pob...
# ...

# %%
#calculamos los años en los que ha habido un detrimento poblacional para todas las series.

# %%
df.fecha[(df.incremento_pob <0) & (df.dato_2 == 'Mujeres')]
# Out:
# 291    2012-06-30
# 292    2012-12-31
# 293    2013-06-30
# 294    2013-12-31
# 295    2014-06-30
# 297    2015-06-30
# 309    2021-06-30
# Name: fecha, dtype: object

# %%
df.fecha[(df.incremento_pob <0) & (df.dato_2 == 'Hombres')]
# Out:
# 143    1990-06-30
# 187    2012-06-30
# 188    2012-12-31
# 189    2013-06-30
# 190    2013-12-31
# 191    2014-06-30
# 192    2014-12-31
# 193    2015-06-30
# 195    2016-06-30
# 197    2017-06-30
# 205    2021-06-30
# Name: fecha, dtype: object

# %%
df.fecha[(df.incremento_pob <0) & (df.dato_2 == 'Total')]
# Out:
# 83     2012-06-30
# 84     2012-12-31
# 85     2013-06-30
# 86     2013-12-31
# 87     2014-06-30
# 88     2014-12-31
# 89     2015-06-30
# 101    2021-06-30
# Name: fecha, dtype: object

# %%
df.fecha[0].year
# Out:
# 1970

# %% [markdown]
# ### 3.- Compara la tasa de crecimiento entre décadas ¿Se detecta variación?

# %%
#Cambiamos la fecha de tipo object a formato fecha para poder procesar las fechas 

pd.to_datetime(df.fecha)
# Out:
# 0     1970-12-31
# 1     1971-06-30
# 2     1971-12-31
# 3     1972-06-30
# 4     1972-12-31
# 5     1973-06-30
# 6     1973-12-31
# 7     1974-06-30
# 8     1974-12-31
# 9     1975-06-30
# 10    1975-12-31
# 11    1976-06-30
# 12    1976-12-31
# 13    1977-06-30
# 14    1977-12-31
# 15    1978-06-30
# 16    1978-12-31
# 17    1979-06-30
# 18    1979-12-31
# 19    1980-06-30
# 20    1980-12-31
# 21    1981-06-30
# 22    1981-12-31
# 23    1982-06-30
# 24    1982-12-31
# 25    1983-06-30
# 26    1983-12-31
# 27    1984-06-30
# 28    1984-12-31
# 29    1985-06-30
# 30    1985-12-31
# 31    1986-06-30
# 32    1986-12-31
# 33    1987-06-30
# 34    1987-12-31
# 35    1988-06-30
# 36    1988-12-31
# 37    1989-06-30
# 38    1989-12-31
# 39    1990-06-30
# 40    1990-12-31
# 41    1991-06-30
# 42    1991-12-31
# 43    1992-06-30
# 44    1992-12-31
# 45    1993-06-30
# 46    1993-12-31
# 47    1994-06-30
# 48    1994-12-31
# 49    1995-06-30
# 50    1995-12-31
# 51    1996-06-30
# ...

# %%
df.fecha = pd.to_datetime(df.fecha)

# %%
df.fecha[0].year
# Out:
# 1970

# %%
df.fecha.apply(lambda x: x.year)   # con esta función extraemos el atributo año de las fechas
# Out:
# 0      1970
# 1      1971
# 2      1971
# 3      1972
# 4      1972
# 5      1973
# 6      1973
# 7      1974
# 8      1974
# 9      1975
# 10     1975
# 11     1976
# 12     1976
# 13     1977
# 14     1977
# 15     1978
# 16     1978
# 17     1979
# 18     1979
# 19     1980
# 20     1980
# 21     1981
# 22     1981
# 23     1982
# 24     1982
# 25     1983
# 26     1983
# 27     1984
# 28     1984
# 29     1985
# 30     1985
# 31     1986
# 32     1986
# 33     1987
# 34     1987
# 35     1988
# 36     1988
# 37     1989
# 38     1989
# 39     1990
# 40     1990
# 41     1991
# 42     1991
# 43     1992
# 44     1992
# 45     1993
# 46     1993
# 47     1994
# 48     1994
# 49     1995
# 50     1995
# 51     1996
# 52     1996
# 53     1997
# 54     1997
# 55     1998
# 56     1998
# 57     1999
# 58     1999
# 59     2000
# 60     2000
# 61     2001
# 62     2001
# 63     2002
# 64     2002
# 65     2003
# 66     2003
# 67     2004
# 68     2004
# 69     2005
# 70     2005
# ...

# %%
df['anyo'] = df.fecha.apply(lambda x: x.year)

# %%
df['mes'] = df.fecha.apply(lambda x: x.month)

# %%
df
# Out:
#          fecha                                               dato   poblacion  \
# 0   1970-12-31  Total Nacional. Todas las edades. Total. Pobla...  34040642.0
# 1   1971-06-30  Total Nacional. Todas las edades. Total. Pobla...  34216856.0
# 2   1971-12-31  Total Nacional. Todas las edades. Total. Pobla...  34408338.0
# 3   1972-06-30  Total Nacional. Todas las edades. Total. Pobla...  34595886.0
# 4   1972-12-31  Total Nacional. Todas las edades. Total. Pobla...  34800600.0
# 5   1973-06-30  Total Nacional. Todas las edades. Total. Pobla...  34980317.0
# 6   1973-12-31  Total Nacional. Todas las edades. Total. Pobla...  35177294.0
# 7   1974-06-30  Total Nacional. Todas las edades. Total. Pobla...  35363890.0
# 8   1974-12-31  Total Nacional. Todas las edades. Total. Pobla...  35569375.0
# 9   1975-06-30  Total Nacional. Todas las edades. Total. Pobla...  35750033.0
# 10  1975-12-31  Total Nacional. Todas las edades. Total. Pobla...  35946425.0
# ...

# %%
df.anyo.unique()  #nos devuelve un listado de los años se la serie
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
### para hacer el analisis de la evolucion a lo largo de las decadas, usamos la función u metodo pandas cat para extraer 
## las decadas de la lista de años

# %%
pd.cut(df.anyo, bins = [1969, 1979, 1989, 1999, 2009, 2019, 2022],
      labels = ['setentas', 'ochentas', 'noventas','dosmil', 'dosmildiez', 'dosmilveinte'])
# Out:
# 0          setentas
# 1          setentas
# 2          setentas
# 3          setentas
# 4          setentas
# 5          setentas
# 6          setentas
# 7          setentas
# 8          setentas
# 9          setentas
# 10         setentas
# 11         setentas
# 12         setentas
# 13         setentas
# 14         setentas
# 15         setentas
# 16         setentas
# 17         setentas
# 18         setentas
# 19         ochentas
# 20         ochentas
# 21         ochentas
# 22         ochentas
# 23         ochentas
# 24         ochentas
# 25         ochentas
# 26         ochentas
# 27         ochentas
# 28         ochentas
# 29         ochentas
# 30         ochentas
# 31         ochentas
# 32         ochentas
# 33         ochentas
# 34         ochentas
# 35         ochentas
# 36         ochentas
# 37         ochentas
# 38         ochentas
# 39         noventas
# 40         noventas
# 41         noventas
# 42         noventas
# 43         noventas
# 44         noventas
# ...

# %%
df['decadas']= pd.cut(df.anyo, bins = [1969, 1979, 1989, 1999, 2009, 2019, 2022],
      labels = ['setentas', 'ochentas', 'noventas','dosmil', 'dosmildiez', 'dosmilveinte'])

# %%
df
# Out:
#          fecha                                               dato   poblacion  \
# 0   1970-12-31  Total Nacional. Todas las edades. Total. Pobla...  34040642.0
# 1   1971-06-30  Total Nacional. Todas las edades. Total. Pobla...  34216856.0
# 2   1971-12-31  Total Nacional. Todas las edades. Total. Pobla...  34408338.0
# 3   1972-06-30  Total Nacional. Todas las edades. Total. Pobla...  34595886.0
# 4   1972-12-31  Total Nacional. Todas las edades. Total. Pobla...  34800600.0
# 5   1973-06-30  Total Nacional. Todas las edades. Total. Pobla...  34980317.0
# 6   1973-12-31  Total Nacional. Todas las edades. Total. Pobla...  35177294.0
# 7   1974-06-30  Total Nacional. Todas las edades. Total. Pobla...  35363890.0
# 8   1974-12-31  Total Nacional. Todas las edades. Total. Pobla...  35569375.0
# 9   1975-06-30  Total Nacional. Todas las edades. Total. Pobla...  35750033.0
# 10  1975-12-31  Total Nacional. Todas las edades. Total. Pobla...  35946425.0
# ...

# %%
df.groupby(['dato_2' ,'decadas']).incremento_pob.sum()
# Out:
# dato_2   decadas
# Hombres  setentas        1681769.0
#          ochentas         716272.0
#          noventas         786554.0
#          dosmil          3155933.0
#          dosmildiez       217041.0
#          dosmilveinte     111314.0
# Mujeres  setentas        1624529.0
#          ochentas         790015.0
#          noventas         830401.0
#          dosmil          2860506.0
#          dosmildiez       628952.0
#          dosmilveinte     171106.0
# Total    setentas        3306298.0
#          ochentas        1506287.0
#          noventas        1616955.0
#          dosmil          6016439.0
#          dosmildiez       845993.0
#          dosmilveinte     282420.0
# Name: incremento_pob, dtype: float64

# %%
## vemos que la decadas de los ochentas y noventas hay un decrecimiento poblacional tanto en hombres como mujeres. 
## Asimismo, em los años dosmil los hombres tienen un repunte mucho mayor que las mujeres con una diferencia de
## 295.247 más hombres que mujeres. Sin embargo, en las decadas de los dosmieldiez, dosmilveinte no hay una gran variación

# %%
df.to_csv('conexion_INE_limpio.csv', index = False)

# %% [markdown]
# ### CONEXIÓN A LA BBDD

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql

# %%
pip install SQLAlchemy==1.4.36

# %%
import mysql.connector

conexion1=mysql.connector.connect(host="localhost", user="root", passwd='Stef182826')
cursor1=conexion1.cursor()
cursor1.execute("show databases")
for base in cursor1:
    print(base)
conexion1.close()
# Out:
# ('call_Center_verde',)
# ('computer_store',)
# ('data_bank',)
# ('hr_unicorn',)
# ('information_schema',)
# ('learndata',)
# ('learndata_crudo',)
# ('linkedin_data',)
# ('mysql',)
# ('ositofeliz',)
# ('performance_schema',)
# ('salesman',)
# ('sandia_clothing',)
# ('tablaprueba1',)
# ('UnicornBurgers',)

# %% [markdown]
# ### Creación de la tabla en la BBDD

# %%
## https://pypi.org/project/pymysql/
## https://pythontic.com/pandas/serialization/mysql

from sqlalchemy import create_engine
import pymysql


# Establecemos los datos de conexión ('mysql+pymysql://usuario:contraseña@host/nombre_BBDD)
sqlEngine = create_engine('mysql+pymysql://root:Stef182826@localhost/tablaprueba1', pool_recycle=3600)
# Establecemos la conexión
dbConnection = sqlEngine.connect()
# Damos nombre a la tabla que vamos a crear
tableName = 'poblacionINE'

try:
    # Creamos la tabla en la BBDD con los datos del dataFrame
    frame = df.to_sql(tableName, dbConnection, if_exists='fail');

except ValueError as vx:
    print(vx)
except Exception as ex:   
    print(ex)
else:
    # Si no da error, imprime que se ha creado correctamente
    print("Table %s created successfully."%tableName);   

finally:
    # En cualquier caso, cierra la conexión con la BBDD
    dbConnection.close()
# Out:
# Table poblacionINE created successfully.
